# %% [markdown]
# # 04 — Feature Extraction Pipeline
# **Phase 1 · Multi-fault Diagnosis of Rotating Machinery**
#
# Goals:
# - Run the full feature extraction pipeline across every MaFaulDa file
# - Combine time-domain and frequency-domain features into a single table
# - Save the result to `outputs/phase1/features.parquet` for use in Phase 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from scipy import signal, stats
from scipy.fft import rfft, rfftfreq

# %%
DATA_ROOT   = Path("../../data/raw")
OUTPUT_PATH = Path("../../outputs/phase1/features.parquet")
SAMPLING_RATE = 50_000  # Hz

CHANNEL_NAMES = [
    "tachometer",
    "underhang_axial", "underhang_radial", "underhang_tangential",
    "overhang_axial",  "overhang_radial",  "overhang_tangential",
    "microphone",
]

ACCEL_CHANNELS = [
    "underhang_axial", "underhang_radial", "underhang_tangential",
    "overhang_axial",  "overhang_radial",  "overhang_tangential",
]

# %%
# TODO: import feature functions from src/phase1/features.py once migrated
# from src.phase1.features import time_domain_features, frequency_domain_features
# from src.phase1.io import load_signal, label_from_path

# %%
# TODO: iterate over all files in DATA_ROOT, extract features, collect into rows

# %%
# TODO: assemble DataFrame, add label columns (fault_type, severity), save to parquet
# OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)
# df_features.to_parquet(OUTPUT_PATH, index=False)
